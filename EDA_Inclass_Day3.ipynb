# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101"> Bivariate Analysis

# %% [markdown]
# * Bivariate analysis is a statistical method that helps you study relationships (correlation) between data sets

# %% [markdown]
# ### Quantitative vs. Quantitative
#     1. Scatterplot
#     2. Line plot

# %% [markdown]
# ### Categorical vs. Quantitative
#     1. Bar chart (on summary statistics)
#     2. Grouped kernel density plots
#     3. Box plots
#     4. Violin plots

# %% [markdown]
# ### Categorical vs. Categorical
#     1. Stacked bar chart
#     2. Grouped bar chart
#     3. Segmented bar chart

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#aec101">Case study 1
#     <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#b53f05"> (Titanic Data Set)

# %% [markdown]
# ### Problem Feature:
# The sinking of the Titanic is one of the most infamous shipwrecks in history. **On April 15, 1912**, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing **1502 out of 2224** passengers and crew. That's why the name DieTanic. This is a very unforgetable disaster that no one in the world can forget.
#
# 1.  **Age** ==>> Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# 2. **Sibsp** ==>> The dataset defines family relations in this way...
#
#     a. Sibling = brother, sister, stepbrother, stepsister
#
#     b. Spouse = husband, wife (mistresses and fiancés were ignored)
#
# 3. **Parch** ==>> The dataset defines family relations in this way...
#
#     a. Parent = mother, father
#
#     b. Child = daughter, son, stepdaughter, stepson
#
#     c. Some children travelled only with a nanny, therefore parch=0 for them.
#
# 4. **Pclass** ==>> A proxy for socio-economic status (SES)
#
#     * 1st = Upper
#     * 2nd = Middle
#     * 3rd = Lower
#
# 5. **Embarked** ==>> nominal datatype
# 6. **Name** ==>> nominal datatype . It could be used in feature engineering to derive the gender from title
# 7. **Sex** ==>>  nominal datatype
# 8. **Ticket** ==>> that have no impact on the outcome variable. Thus, they will be excluded from analysis
# 9. **Cabin** ==>>  is a nominal datatype that can be used in feature engineering
# 11. **Fare** ==>>  Indicating the fare
# 12. **PassengerID ** ==>> have no impact on the outcome variable. Thus, it will be excluded from analysis
# 11. **Survival** is ==>> **[dependent variable], 0 or 1

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.1 Load the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.2 Import the dataset

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.3 Check the shape of the dataset

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.4 How to view the statistical characteristics of the data?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.5 How to check the summary statistics for Age column ?

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.6 How to check the column names?

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.7 What are the Numerical Features,Categorical Features and  Alphanumeric Features in the dataframe ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.8 Categorical vs. Quantitative

# %% [markdown]
#     * Categorical: Survived, Sex, and Embarked. Ordinal: Pclass.
#     * Numerical Features: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8a) Create a  bar plot for  Sex Vs Survived. And Write your Observation?

# %% [markdown]
#  print the percentage of male vs female survived

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.show()

# %% [markdown]
# Inference : The percentage of male survived is less comapred to the percentage of femlae survived.
#     Approx. 20% male survived
#     Approx. 70% female survived

# %%
df[['Sex','Survived']].groupby('Sex').mean().plot(kind='bar')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8d) Create a bar plot for Pclass Vs Survived.And write your Observation?

# %%
# print the percentages of first, second adnt third class

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
plt.show()

# %%
df[['Pclass','Survived']].groupby('Pclass').mean().plot(kind='bar')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8c) Create Bar plot for both Survived vs Sex and Sex:Survived vs Dead. And Write your Observations?

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.show()

# %%
sns.countplot('Sex', hue='Survived', data=df)
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.barplot(x='Sex', y='Survived', data=df, ax=axes[0])
sns.countplot('Sex', hue='Survived', data=df, ax=axes[1])
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8d) Create a Bar plot to check the following:
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Number Of Passengers vs  Pclass
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  Pclass:Survived vs Dead.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.countplot(x='Pclass',  data=df, ax=axes[0])
sns.countplot('Pclass', hue='Survived', data=df, ax=axes[1])
plt.show()

# %% [markdown]
# Inference:
# Highest People survived are from Pclass1, followed by Pclass2 and then Pclass3.
# Highest people died are from Pclass3
#
# In Pclass1 the percentage of people survived is more than the percentage of people dead.
# In Pclass2 the percentage of people survived is little less compared to the percentage of people dead.
# In Pclass3 the percentage of people survived is very less comapred to the percentage of people dead.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.8e) Create violinplot plot for checking
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    a) Pclass vs. Age sliced by Survived
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">    b) Sex vs Age sliced by Survived. And write your Observations?

# %%
plt.figure(figsize=(15,5))
sns.violinplot('Pclass', 'Age', hue='Survived', data=df)
plt.show()

# %% [markdown]
# Inference:
# In Pclass2, all people whoes age is less than 18 has survived. Most of the people with age less than 18 has survived.

# %%
plt.figure(figsize=(15,5))
sns.violinplot('Sex', 'Age', hue='Survived', data=df, split=True )
plt.show()

# %% [markdown]
# Inference:
# Most of the male below 20 has survived. Male ageing older than 80 have survived.
# The percentage of female who survived around age 20 is more likely equal to the percentage of female died who are around age 20

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.8f) Create Bar(count) plot for checking  Embarked vs (No. of passengers, sex, Survived , Pclass). And write your Observations?

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
sns.countplot('Embarked', hue='Sex', data=df)
plt.show()

# %%
sns.countplot('Embarked', hue='Survived', data=df)
plt.show()

# %%
sns.countplot('Embarked', hue='Pclass', data=df)
plt.show()

# %% [markdown]
# ### Box Plot
# A box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.8 g)Create a box plot for pclass vs Age. And write your Observations?

# %%
sns.boxplot('Pclass', 'Age', data=df)
sns.stripplot('Pclass', 'Age', data=df)
plt.show()

# %% [markdown]
# Inference:
#     Mean of Pclass 1 is around 40, whereas for Pclass2 is around 30 and for Pclass 3 it is around 25.
#     The Pclass 1 data is wide spread and the majority of data lies between 30 and 50, whereas for Pclass 2 and 3 it is between
#     25-40 and 20-35 respectively.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.9 Categorical vs. Categorical

# %% [markdown]
# ### Stacked bar chart

# %% [markdown]
# A stacked bar chart, also known as a stacked bar graph, is a graph that is used to break down and compare parts of a whole. Each bar in the chart represents a whole, and segments in the bar represent different parts or categories of that whole. Different colors are used to illustrate the different categories in the bar.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.9a) Create a Stacked bar chart Sex Vs Survived. And write  your Observations?

# %%
# create crosstab
ct = pd.crosstab(df['Sex'], df['Survived'])
print(ct)
ct.plot(kind='bar',stacked=True)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
ct.div(ct.sum(1), axis=0)
# Out:
# Survived         0         1
# Sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
ct.div(ct.sum(1), axis=0).plot(kind='bar',stacked=True)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101"> 1.10 Quantitative vs. Quantitative

# %% [markdown]
#     Numerical Features: Age (Continuous), Fare (Continuous)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">  1.10a) Create a scatter plot for showing age & fare with target varialble. And write your Observations?

# %%
sns.scatterplot(y="Age", x='Fare', hue='Survived', data=df)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.11 Frequency tables

# %% [markdown]
# 1. One-Way Tables
# 2. Two-Way Tables

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101"> 1.11 a) Create frequency tables (also known as crosstab) in pandas using the pd.crosstab() function.

# %%
counts = df['Survived'].value_counts()
counts
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# #### Two-Way Tables
#
# Two-way frequency tables, also called contingency tables, are tables of counts with two dimensions where each dimension is a different variable. Two-way tables can give you insight into the relationship between two variables.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.2em;color:#aec101">1.11b )Create Two-way-table for survival vs sex?

# %%
pd.crosstab(df['Survived'],df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 Check Correlation plot using Heat map?

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#aec101">1.12 a) Check the pairplot

# %%
sns.heatmap(df.corr(), annot=True)

# %%
sns.pairplot(df, diag_kind='kde', hue='Survived')
# Out:
# C:\Users\Karangula\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Karangula\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Karangula\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\Karangula\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
